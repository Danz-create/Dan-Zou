# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/GeoAI-Book/blob/main/book/foundations/setup.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/GeoAI-Book/main?urlpath=lab/tree/book/foundations/setup.ipynb)

# %% [markdown]
# # Setting Up Your Environment
#
# ## Introduction
#
# ## Learning Objectives
#
# ## Hardware Requirements
#
# ### Minimum Requirements
#
# ### Recommended Requirements
#
# ### Cloud Alternatives
#
# ## Installing NVIDIA Drivers
#
# ### macOS
#
# ### Windows
#
# ```bash
# nvidia-smi
# ```
#
# ### Linux
#
# ```bash
# sudo apt update
# sudo ubuntu-drivers install
# ```
#
# ```bash
# sudo apt install nvidia-driver-580
# ```
#
# ```bash
# sudo reboot
# ```
#
# ```bash
# sudo dnf install https://download1.rpmfusion.org/free/fedora/rpmfusion-free-release-$(rpm -E %fedora).noarch.rpm \
#     https://download1.rpmfusion.org/nonfree/fedora/rpmfusion-nonfree-release-$(rpm -E %fedora).noarch.rpm
# sudo dnf install akmod-nvidia
# ```
#
# ```bash
# sudo pacman -S nvidia nvidia-utils
# ```
#
# ### Verifying the Driver Installation
#
# ```bash
# nvidia-smi
# ```
#
# ## Installing Python with Miniconda
#
# ### Windows Installation
#
#    ```bash
#    curl https://repo.anaconda.com/miniconda/Miniconda3-latest-Windows-x86_64.exe -o .\miniconda.exe
#    start /wait "" .\miniconda.exe /S
#    del .\miniconda.exe
#    ```
#
#    ```bash
#    conda --version
#    python --version
#    ```
#
# ### macOS Installation
#
# ```bash
# mkdir -p ~/miniconda3
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh -o ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm ~/miniconda3/miniconda.sh
# ```
#
# ```bash
# source ~/miniconda3/bin/activate
# conda init --all
# ```
#
# ```bash
# conda --version
# python --version
# ```
#
# ### Linux Installation
#
# ```bash
# mkdir -p ~/miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm ~/miniconda3/miniconda.sh
# ```
#
# ```bash
# source ~/miniconda3/bin/activate
# conda init --all
# ```
#
# ```bash
# conda --version
# python --version
# ```
#
# ## Creating a Conda Environment
#
# ```bash
# conda create -n geoai python=3.13 -y
# ```
#
# ```bash
# conda activate geoai
# ```
#
# ```bash
# conda deactivate
# ```
#
# ## Installing GeoAI and PyTorch with GPU Support
#
# ```bash
# conda activate geoai
# ```
#
# ### Checking Your GPU
#
# ```bash
# nvidia-smi
# ```
#
# ### Installing GeoAI and PyTorch with CUDA
#
# ```bash
# conda install -c conda-forge geoai segment-geospatial "pytorch=*=cuda*"
# ```
#
# ```bash
# conda install -c conda-forge geoai segment-geospatial "pytorch=2.7.0=cuda128"
# ```
#
# ### Installing GeoAI and PyTorch for CPU Only
#
# ```bash
# conda install -c conda-forge geoai segment-geospatial
# ```
#
# ### Verifying GPU Access
#
# ```bash
# python -c "import torch; print(f'PyTorch {torch.__version__}'); print(f'CUDA available: {torch.cuda.is_available()}'); print(f'GPU: {torch.cuda.get_device_name(0)}' if torch.cuda.is_available() else 'CPU only')"
# ```
#
# ## Installing uv as an Alternative Package Manager
#
# ```bash
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
#
# ```bash
# pip install uv
# ```
#
# ```bash
# uv venv --python 3.13
# ```
#
# ```bash
# source .venv/bin/activate
# ```
#
# ```bash
# uv pip install geoai-py segment-geospatial jupyterlab
# ```
#
# ## Setting Up Jupyter
#
# ```bash
# jupyter lab
# ```

# %%
pip install uv
# Out:
# Requirement already satisfied: uv in /usr/local/lib/python3.12/dist-packages (0.11.12)

# %%
pip install geoai-py segment-geospatial jupyterlab
# Out:
# Collecting geoai-py
#   Downloading geoai_py-0.37.2-py2.py3-none-any.whl.metadata (13 kB)
# Collecting segment-geospatial
#   Downloading segment_geospatial-1.3.2-py2.py3-none-any.whl.metadata (16 kB)
# Collecting jupyterlab
#   Downloading jupyterlab-4.5.7-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.0.8)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geoai-py) (8.3.3)
# Collecting contextily (from geoai-py)
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: datasets>=3.0 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.0.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.1.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.11.0)
# Collecting jupyter-server-proxy (from geoai-py)
#   Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting leafmap>=0.57.1 (from geoai-py)
#   Downloading leafmap-0.62.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from geoai-py)
#   Downloading localtileserver-1.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0)
# Collecting maplibre (from geoai-py)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.13.0.92)
# Collecting overturemaps (from geoai-py)
#   Downloading overturemaps-1.0.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting planetary-computer (from geoai-py)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geoai-py) (18.1.0)
# Collecting pystac-client (from geoai-py)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.5.0)
# Collecting rioxarray (from geoai-py)
#   Downloading rioxarray-0.22.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.6.1)
# Collecting smoothify (from geoai-py)
#   Downloading smoothify-0.2.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.0.26)
# Requirement already satisfied: tokenizers>=0.22.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.22.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0+cpu)
# Collecting torchgeo (from geoai-py)
#   Downloading torchgeo-0.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting torchinfo (from geoai-py)
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.67.3)
# Requirement already satisfied: transformers>=4.57.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (5.0.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (5.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (2.0.2)
# Collecting patool (from segment-geospatial)
#   Downloading patool-4.0.4-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (11.3.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (3.7.2)
# Collecting segment_anything (from segment-geospatial)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (2.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (0.25.0+cpu)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (2026.3.0)
# Collecting async-lru>=1.0.0 (from jupyterlab)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (6.17.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (5.9.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab)
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (26.1)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (75.2.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (6.5.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (5.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.29.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0->geoai-py) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (6.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (1.4.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (4.15.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (26.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab) (4.9.6)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab)
#   Downloading json5-0.14.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.26.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.12.45)
# Collecting duckdb>=1.4.1 (from leafmap>=0.57.1->geoai-py)
#   Downloading duckdb-1.5.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.20.0)
# Collecting geojson (from leafmap>=0.57.1->geoai-py)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.20.0)
# Collecting ipyvue>=1.12.0 (from leafmap>=0.57.1->geoai-py)
#   Downloading ipyvue-1.12.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipyvuetify (from leafmap>=0.57.1->geoai-py)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (7.7.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (5.24.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.11.2)
# Collecting whiteboxgui (from leafmap>=0.57.1->geoai-py)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (0.7.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (6.5.16)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (2.4.1)
# Collecting mercantile (from contextily->geoai-py)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (1.5.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->segment-geospatial) (4.13.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (0.12.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (3.13.5)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->geoai-py)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: fastapi>=0.100.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (0.136.1)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (0.46.0)
# Collecting jupyter-loopback>=0.3.3 (from jupyter-loopback[comm]>=0.3.3->localtileserver->geoai-py)
#   Downloading jupyter_loopback-0.3.3-py3-none-any.whl.metadata (7.6 kB)
# Collecting rio-tiler (from localtileserver->geoai-py)
#   Downloading rio_tiler-9.0.6-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver->geoai-py)
#   Downloading rio_cogeo-7.0.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting server-thread (from localtileserver->geoai-py)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify->geoai-py) (3.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geoai-py) (3.6.0)
# Requirement already satisfied: branca in /usr/local/lib/python3.12/dist-packages (from maplibre->geoai-py) (0.8.2)
# Collecting eval-type-backport (from maplibre->geoai-py)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (2.9.0.post0)
# Collecting colorama>=0.4.6 (from overturemaps->geoai-py)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from overturemaps->geoai-py) (3.11.8)
# Collecting pyfiglet>=1.0.2 (from overturemaps->geoai-py)
#   Downloading pyfiglet-1.0.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting pystac>=1.0.0 (from planetary-computer->geoai-py)
#   Downloading pystac-1.14.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pytz>=2020.5 in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (2025.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (1.2.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (26.1.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (0.7.2)
# Collecting xarray>=2026.2 (from rioxarray->geoai-py)
#   Downloading xarray-2026.4.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (0.5)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (1.14.0)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (0.8.2)
# Collecting jsonargparse>=4.35 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py)
#   Downloading jsonargparse-4.48.0-py3-none-any.whl.metadata (12 kB)
# Collecting kornia>=0.8.2 (from torchgeo->geoai-py)
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo->geoai-py)
#   Downloading lightly-1.5.23-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 4.4 MB/s eta 0:00:00
# Collecting lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2 (from torchgeo->geoai-py)
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.3 MB/s eta 0:00:00
# Collecting segmentation-models-pytorch>=0.5 (from torchgeo->geoai-py)
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting torchmetrics>=1.2 (from torchgeo->geoai-py)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.23.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (3.0.16)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py) (0.18.0)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py)
#   Downloading typeshed_client-2.11.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap>=0.57.1->geoai-py) (0.15.1)
# Collecting kornia_rs>=0.1.9 (from kornia>=0.8.2->torchgeo->geoai-py)
#   Downloading kornia_rs-0.1.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Collecting pytorch_lightning>=1.0.4 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.5.0)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading aenum-3.1.17-py3-none-any.whl.metadata (3.8 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2->torchgeo->geoai-py)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0->geoai-py) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0->geoai-py) (3.4.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->geoai-py) (1.3.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->segment-geospatial) (2.8.3)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap>=0.57.1->geoai-py) (0.2.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily->geoai-py) (2.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap>=0.57.1->geoai-py) (0.20.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap>=0.57.1->geoai-py) (9.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver->geoai-py)
#   Downloading morecantile-7.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (6.2.6)
# Collecting color-operations (from rio-tiler->localtileserver->geoai-py)
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (2.14.1)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver->geoai-py) (3.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->geoai-py) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->geoai-py) (13.9.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (15.0.1)
# Collecting ipytree (from whiteboxgui->leafmap>=0.57.1->geoai-py)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->leafmap>=0.57.1->geoai-py)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (4.9.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.6)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (25.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->geoai-py) (4.0.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[signatures]>=4.35->torchgeo->geoai-py) (7.1.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.57.1->geoai-py) (6.5.7)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->geoai-py) (0.1.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.57.1->geoai-py) (1.3.3)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Downloading geoai_py-0.37.2-py2.py3-none-any.whl (601 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.8/601.8 kB 53.0 MB/s eta 0:00:00
# Downloading segment_geospatial-1.3.2-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 kB 19.4 MB/s eta 0:00:00
# Downloading jupyterlab-4.5.7-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 134.9 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 9.0 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.6 MB/s eta 0:00:00
# Downloading leafmap-0.62.0-py2.py3-none-any.whl (667 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.5/667.5 kB 32.8 MB/s eta 0:00:00
# Downloading contextily-1.7.0-py3-none-any.whl (16 kB)
# Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.7 MB/s eta 0:00:00
# Downloading localtileserver-1.0.0-py3-none-any.whl (33.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 27.5 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.4 MB/s eta 0:00:00
# Downloading overturemaps-1.0.0-py3-none-any.whl (25 kB)
# Downloading patool-4.0.4-py2.py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 10.4 MB/s eta 0:00:00
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.0 MB/s eta 0:00:00
# Downloading rioxarray-0.22.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 8.3 MB/s eta 0:00:00
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Downloading smoothify-0.2.2-py3-none-any.whl (16 kB)
# Downloading torchgeo-0.9.0-py3-none-any.whl (688 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.1/688.1 kB 55.2 MB/s eta 0:00:00
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading duckdb-1.5.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 44.6 MB/s eta 0:00:00
# Downloading ipyvue-1.12.0-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 64.6 MB/s eta 0:00:00
# Downloading json5-0.14.0-py3-none-any.whl (36 kB)
# Downloading jsonargparse-4.48.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 16.8 MB/s eta 0:00:00
# Downloading jupyter_loopback-0.3.3-py3-none-any.whl (37 kB)
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 72.1 MB/s eta 0:00:00
# Downloading lightly-1.5.23-py3-none-any.whl (863 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.6/863.6 kB 61.0 MB/s eta 0:00:00
# Downloading lightning-2.6.1-py3-none-any.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 72.0 MB/s eta 0:00:00
# Downloading pyfiglet-1.0.4-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 102.4 MB/s eta 0:00:00
# Downloading pystac-1.14.3-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 26.6 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 7.8 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 60.6 MB/s eta 0:00:00
# Downloading xarray-2026.4.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 92.5 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 98.3 MB/s eta 0:00:00
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rio_cogeo-7.0.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-9.0.6-py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 29.0 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 13.8 MB/s eta 0:00:00
# Downloading aenum-3.1.17-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 17.2 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.4 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 122.9 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 87.5 MB/s eta 0:00:00
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading morecantile-7.0.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 6.9 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 62.3 MB/s eta 0:00:00
# Downloading typeshed_client-2.11.0-py3-none-any.whl (787 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.6/787.6 kB 63.1 MB/s eta 0:00:00
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 23.0 MB/s eta 0:00:00
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.1 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: segment_anything, aenum, whitebox, typeshed-client, torchinfo, simpervisor, pyfiglet, patool, mercantile, lightning-utilities, lightly_utils, kornia_rs, jsonargparse, json5, jedi, geojson, eval-type-backport, duckdb, colorama, color-operations, async-lru, server-thread, pystac, overturemaps, hydra-core, xarray, torchmetrics, morecantile, maplibre, kornia, contextily, smoothify, rioxarray, rio-tiler, rio-cogeo, pytorch_lightning, segment-geospatial, pystac-client, lightning, lightly, segmentation-models-pytorch, planetary-computer, torchgeo, jupyterlab-server, jupyter-server-proxy, jupyter-lsp, jupyter-loopback, jupyterlab, ipyvue, ipytree, whiteboxgui, ipyvuetify, localtileserver, leafmap, geoai-py
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.12.0
#     Uninstalling xarray-2025.12.0:
#       Successfully uninstalled xarray-2025.12.0
# Successfully installed aenum-3.1.17 async-lru-2.3.0 color-operations-0.2.0 colorama-0.4.6 contextily-1.7.0 duckdb-1.5.2 eval-type-backport-0.3.1 geoai-py-0.37.2 geojson-3.2.0 hydra-core-1.3.2 ipytree-0.2.2 ipyvue-1.12.0 ipyvuetify-1.11.3 jedi-0.20.0 json5-0.14.0 jsonargparse-4.48.0 jupyter-loopback-0.3.3 jupyter-lsp-2.3.1 jupyter-server-proxy-4.5.0 jupyterlab-4.5.7 jupyterlab-server-2.28.0 kornia-0.8.2 kornia_rs-0.1.11 leafmap-0.62.0 lightly-1.5.23 lightly_utils-0.0.2 lightning-2.6.1 lightning-utilities-0.15.3 localtileserver-1.0.0 maplibre-0.3.6 mercantile-1.2.1 morecantile-7.0.3 overturemaps-1.0.0 patool-4.0.4 planetary-computer-1.0.0 pyfiglet-1.0.4 pystac-1.14.3 pystac-client-0.9.0 pytorch_lightning-2.6.1 rio-cogeo-7.0.2 rio-tiler-9.0.6 rioxarray-0.22.0 segment-geospatial-1.3.2 segment_anything-1.0 segmentation-models-pytorch-0.5.0 server-thread-0.3.0 simpervisor-1.0.0 smoothify-0.2.2 torchgeo-0.9.0 torchinfo-1.8.0 torchmetrics-1.9.0 typeshed-client-2.11.0 whitebox-2.3.6 whiteboxgui-2.3.0 xarray-2026.4.0

# %%
import torch
import geoai

print(torch.cuda.is_available())
print(geoai.__version__)
# Out:
# False
# 0.37.2

# %% [markdown]
# ## Installing Visual Studio Code
#
# ### Download and Installation
#
# ### Recommended Extensions
#
# ```bash
# code --install-extension ms-python.python
# code --install-extension ms-toolsai.jupyter
# code --install-extension charliermarsh.ruff
# ```
#
# ## Verifying Your Setup

# %%
import sys
import importlib

print(f"Python version: {sys.version}\n")

# Check core packages
packages = {
    "torch": "PyTorch",
    "torchvision": "TorchVision",
    "geoai": "GeoAI",
    "leafmap": "Leafmap",
    "geopandas": "GeoPandas",
    "rasterio": "Rasterio",
    "samgeo": "Segment-Geospatial",
    "torchgeo": "TorchGeo",
}

for module_name, display_name in packages.items():
    try:
        mod = importlib.import_module(module_name)
        version = getattr(mod, "__version__", "installed")
        print(f"  {display_name}: {version}")
    except ImportError:
        print(f"  {display_name}: NOT FOUND")

# Check GPU availability
import torch

print(f"\nCUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")
else:
    print("Running in CPU-only mode.")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
#   PyTorch: 2.10.0+cpu
#   TorchVision: 0.25.0+cpu
#   GeoAI: 0.37.2
#   Leafmap: 0.62.0
#   GeoPandas: 1.1.3
#   Rasterio: 1.5.0
#   Segment-Geospatial: 1.3.2
#   TorchGeo: 0.9.0
#
# CUDA available: False
# Running in CPU-only mode.

# %%
import leafmap

m = leafmap.Map(center=[40, -100], zoom=4)
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ## Exercises
#
# ### Exercise 1: Install and Verify Your Environment
#
# ### Exercise 2: Check GPU Availability
#
# ### Exercise 3: Explore Conda Environment Management
#
# ### Exercise 4: Create an Interactive Map
